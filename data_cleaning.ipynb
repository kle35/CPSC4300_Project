# %%
import pandas as pd
from datetime import datetime

# %%
data = pd.read_csv('airpod_reviews.csv')

# %%
data.head()
# Out:
#     username_name     username_rating  \
# 0  Asia underwood  4.0 out of 5 stars
# 1           Katie  4.0 out of 5 stars
# 2   Sean Connolly  4.0 out of 5 stars
# 3        Michelle  5.0 out of 5 stars
# 4          Jayden  5.0 out of 5 stars
#
#                            username_inital_statement  \
# 0  It has good noise cancellation the only proble...
# 1                              Love these Headphones
# 2                                              Solid
# 3                                          BUY IT RN
# 4                       Greta product slightly dirty
#
#                                     username_country  username_verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...  Verified Purchase
# 1  Reviewed in the United States 🇺🇸 on February 2...  Verified Purchase
# 2  Reviewed in the United States 🇺🇸 on December 1...  Verified Purchase
# 3  Reviewed in the United States 🇺🇸 on January 17...  Verified Purchase
# ...

# %%
data.count()
# Out:
# username_name                1996
# username_rating              1996
# username_inital_statement    1996
# username_country             1996
# username_verified            1941
# username_review              1979
# username_usefulness           424
# dtype: int64

# %%
data.shape[0]
# Out:
# 1996

# %%
data = data.rename(columns={
    'username_name':'username',
    'username_rating':'rating',
    'username_inital_statement':'initial_statement',
    'username_verified':'verified',
    'username_review':'review',
    'username_usefulness':'usefulness',
})

# %%
data.head()
# Out:
#          username              rating  \
# 0  Asia underwood  4.0 out of 5 stars
# 1           Katie  4.0 out of 5 stars
# 2   Sean Connolly  4.0 out of 5 stars
# 3        Michelle  5.0 out of 5 stars
# 4          Jayden  5.0 out of 5 stars
#
#                                    initial_statement  \
# 0  It has good noise cancellation the only proble...
# 1                              Love these Headphones
# 2                                              Solid
# 3                                          BUY IT RN
# 4                       Greta product slightly dirty
#
#                                     username_country           verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...  Verified Purchase
# 1  Reviewed in the United States 🇺🇸 on February 2...  Verified Purchase
# 2  Reviewed in the United States 🇺🇸 on December 1...  Verified Purchase
# 3  Reviewed in the United States 🇺🇸 on January 17...  Verified Purchase
# ...

# %%
data['rating'] = data['rating'].str[0]

# %%
data.head()
# Out:
#          username rating                                  initial_statement  \
# 0  Asia underwood      4  It has good noise cancellation the only proble...
# 1           Katie      4                              Love these Headphones
# 2   Sean Connolly      4                                              Solid
# 3        Michelle      5                                          BUY IT RN
# 4          Jayden      5                       Greta product slightly dirty
#
#                                     username_country           verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...  Verified Purchase
# 1  Reviewed in the United States 🇺🇸 on February 2...  Verified Purchase
# 2  Reviewed in the United States 🇺🇸 on December 1...  Verified Purchase
# 3  Reviewed in the United States 🇺🇸 on January 17...  Verified Purchase
# 4  Reviewed in the United States 🇺🇸 on February 1...  Verified Purchase
#
#                                               review  \
# ...

# %%
data.head()
# Out:
#          username rating                                  initial_statement  \
# 0  Asia underwood      4  It has good noise cancellation the only proble...
# 1           Katie      4                              Love these Headphones
# 2   Sean Connolly      4                                              Solid
# 3        Michelle      5                                          BUY IT RN
# 4          Jayden      5                       Greta product slightly dirty
#
#                                     username_country           verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...  Verified Purchase
# 1  Reviewed in the United States 🇺🇸 on February 2...  Verified Purchase
# 2  Reviewed in the United States 🇺🇸 on December 1...  Verified Purchase
# 3  Reviewed in the United States 🇺🇸 on January 17...  Verified Purchase
# 4  Reviewed in the United States 🇺🇸 on February 1...  Verified Purchase
#
#                                               review  \
# ...

# %%
type(data['rating'])
# Out:
# pandas.core.series.Series

# %%
data['rating'] = data['rating'].astype(int)

# %%
data['verified'] = data['verified'].replace({'Verified Purchase':1, '':0})

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#                                     username_country verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...        1
# 1  Reviewed in the United States 🇺🇸 on February 2...        1
# 2  Reviewed in the United States 🇺🇸 on December 1...        1
# 3  Reviewed in the United States 🇺🇸 on January 17...        1
# 4  Reviewed in the United States 🇺🇸 on February 1...        1
#
#                                               review  \
# 0  so when I bought these , I knew what i wanted ...
# ...

# %%
data.tail()
# Out:
#                     username  rating  \
# 1991  PEDRO VALDOVINOS GAONA       2
# 1992                  maac08       5
# 1993             Maximiliano       1
# 1994            Antonio Meré       5
# 1995                   diego       1
#
#                                       initial_statement  \
# 1991        Que el producto esté en buenas condiciones.
# 1992                                  muy recomendables
# 1993  La caja de los audífonos me llegó , de que est...
# 1994                                          Excelente
# 1995         Audifono derecho COMPLETAMENTE inservible.
#
#                                  username_country verified  \
# 1991       Reviewed in Mexico 🇲🇽 on June 24, 2021        1
# 1992        Reviewed in Mexico 🇲🇽 on June 1, 2021        1
# 1993  Reviewed in Mexico 🇲🇽 on September 19, 2022        1
# 1994        Reviewed in Mexico 🇲🇽 on May 22, 2021        1
# 1995     Reviewed in Mexico 🇲🇽 on October 4, 2021        1
#
# ...

# %%
data['verified'].isnull().sum()
# Out:
# 55

# %%
data['verified'] = data['verified'].fillna(0)

# %%
data['verified'].isnull().sum()
# Out:
# 0

# %%
data['username'].isnull().sum()
# Out:
# 0

# %%
data['initial_statement'].isnull().sum()
# Out:
# 0

# %%
data.count()
# Out:
# username             1996
# rating               1996
# initial_statement    1996
# username_country     1996
# verified             1996
# review               1979
# usefulness            424
# dtype: int64

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#                                     username_country verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...        1
# 1  Reviewed in the United States 🇺🇸 on February 2...        1
# 2  Reviewed in the United States 🇺🇸 on December 1...        1
# 3  Reviewed in the United States 🇺🇸 on January 17...        1
# 4  Reviewed in the United States 🇺🇸 on February 1...        1
#
#                                               review  \
# 0  so when I bought these , I knew what i wanted ...
# ...

# %%
data = data.rename(columns={'username_country':'country'})

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#                                              country verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...        1
# 1  Reviewed in the United States 🇺🇸 on February 2...        1
# 2  Reviewed in the United States 🇺🇸 on December 1...        1
# 3  Reviewed in the United States 🇺🇸 on January 17...        1
# 4  Reviewed in the United States 🇺🇸 on February 1...        1
#
#                                               review  \
# 0  so when I bought these , I knew what i wanted ...
# ...

# %%
data['date'] = data['country'].str.split(" ").str[-3:].str.join(" ")

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#                                              country verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...        1
# 1  Reviewed in the United States 🇺🇸 on February 2...        1
# 2  Reviewed in the United States 🇺🇸 on December 1...        1
# 3  Reviewed in the United States 🇺🇸 on January 17...        1
# 4  Reviewed in the United States 🇺🇸 on February 1...        1
#
#                                               review  \
# 0  so when I bought these , I knew what i wanted ...
# ...

# %%
data["date"] = pd.to_datetime(data["date"])

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#                                              country verified  \
# 0  Reviewed in the United States 🇺🇸 on February 1...        1
# 1  Reviewed in the United States 🇺🇸 on February 2...        1
# 2  Reviewed in the United States 🇺🇸 on December 1...        1
# 3  Reviewed in the United States 🇺🇸 on January 17...        1
# 4  Reviewed in the United States 🇺🇸 on February 1...        1
#
#                                               review  \
# 0  so when I bought these , I knew what i wanted ...
# ...

# %%
data['country'] = data['country'].str.split(" ").str[3:5].str.join(" ")

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#          country verified                                             review  \
# 0  United States        1  so when I bought these , I knew what i wanted ...
# 1  United States        1  I bought these headphones last year and they h...
# 2  United States        1  The noise cancellation feature is very cool, a...
# 3  United States        1  i was a little bit skeptical at first because ...
# 4  United States        1  Everything works! The only down sid Eid there ...
#
# ...

# %%
data['usefulness'] = data['usefulness'].str.split(" ").str.get(0)

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#          country verified                                             review  \
# 0  United States        1  so when I bought these , I knew what i wanted ...
# 1  United States        1  I bought these headphones last year and they h...
# 2  United States        1  The noise cancellation feature is very cool, a...
# 3  United States        1  i was a little bit skeptical at first because ...
# 4  United States        1  Everything works! The only down sid Eid there ...
#
#   usefulness       date
# ...

# %%
data['usefulness'].fillna(0)
# Out:
# 0         7
# 1         6
# 2         6
# 3         7
# 4         0
#        ...
# 1991      0
# 1992      0
# 1993    One
# 1994      0
# 1995    One
# Name: usefulness, Length: 1996, dtype: object

# %%
data.count()
# Out:
# username             1996
# rating               1996
# initial_statement    1996
# country              1996
# verified             1996
# review               1979
# usefulness            424
# date                 1996
# dtype: int64

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#          country verified                                             review  \
# 0  United States        1  so when I bought these , I knew what i wanted ...
# 1  United States        1  I bought these headphones last year and they h...
# 2  United States        1  The noise cancellation feature is very cool, a...
# 3  United States        1  i was a little bit skeptical at first because ...
# 4  United States        1  Everything works! The only down sid Eid there ...
#
#   usefulness       date
# ...

# %%
data['usefulness'] = data['usefulness'].replace({'One':1})

# %%
data.count()
# Out:
# username             1996
# rating               1996
# initial_statement    1996
# country              1996
# verified             1996
# review               1979
# usefulness            424
# date                 1996
# dtype: int64

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#          country verified                                             review  \
# 0  United States        1  so when I bought these , I knew what i wanted ...
# 1  United States        1  I bought these headphones last year and they h...
# 2  United States        1  The noise cancellation feature is very cool, a...
# 3  United States        1  i was a little bit skeptical at first because ...
# 4  United States        1  Everything works! The only down sid Eid there ...
#
#   usefulness       date
# ...

# %%
data['usefulness'] = data['usefulness'].fillna(0)

# %%
data.head()
# Out:
#          username  rating                                  initial_statement  \
# 0  Asia underwood       4  It has good noise cancellation the only proble...
# 1           Katie       4                              Love these Headphones
# 2   Sean Connolly       4                                              Solid
# 3        Michelle       5                                          BUY IT RN
# 4          Jayden       5                       Greta product slightly dirty
#
#          country verified                                             review  \
# 0  United States        1  so when I bought these , I knew what i wanted ...
# 1  United States        1  I bought these headphones last year and they h...
# 2  United States        1  The noise cancellation feature is very cool, a...
# 3  United States        1  i was a little bit skeptical at first because ...
# 4  United States        1  Everything works! The only down sid Eid there ...
#
#   usefulness       date
# ...

# %%
data.count()
# Out:
# username             1996
# rating               1996
# initial_statement    1996
# country              1996
# verified             1996
# review               1979
# usefulness           1996
# date                 1996
# dtype: int64

# %%
data
# Out:
#                     username  rating  \
# 0             Asia underwood       4
# 1                      Katie       4
# 2              Sean Connolly       4
# 3                   Michelle       5
# 4                     Jayden       5
# ...                      ...     ...
# 1991  PEDRO VALDOVINOS GAONA       2
# 1992                  maac08       5
# 1993             Maximiliano       1
# 1994            Antonio Meré       5
# 1995                   diego       1
#
#                                       initial_statement        country  \
# 0     It has good noise cancellation the only proble...  United States
# 1                                 Love these Headphones  United States
# 2                                                 Solid  United States
# 3                                             BUY IT RN  United States
# 4                          Greta product slightly dirty  United States
# ...                                                 ...            ...
# ...

# %%
data['country'].unique()
# Out:
# array(['United States', '🇲🇽 on', '🇨🇦 on'], dtype=object)

# %%
data.tail()
# Out:
#                     username  rating  \
# 1991  PEDRO VALDOVINOS GAONA       2
# 1992                  maac08       5
# 1993             Maximiliano       1
# 1994            Antonio Meré       5
# 1995                   diego       1
#
#                                       initial_statement country verified  \
# 1991        Que el producto esté en buenas condiciones.   🇲🇽 on        1
# 1992                                  muy recomendables   🇲🇽 on        1
# 1993  La caja de los audífonos me llegó , de que est...   🇲🇽 on        1
# 1994                                          Excelente   🇲🇽 on        1
# 1995         Audifono derecho COMPLETAMENTE inservible.   🇲🇽 on        1
#
#                                                  review usefulness       date
# 1991  El producto se descargaba muy rápido incluso l...          0 2021-06-24
# 1992                   excelentes para usar en llamadas          0 2021-06-01
# ...

# %%
data['country'] = data['country'].replace({'🇲🇽 on':'Mexico', '🇨🇦 on':'Canada'})

# %%
data['country'].unique()
# Out:
# array(['United States', 'Mexico', 'Canada'], dtype=object)

# %%
data.to_csv('airpod_reviews_cleaned.csv', index=False)

# %%
data[data['country']=='Mexico'].count()
# Out:
# username             135
# rating               135
# initial_statement    135
# country              135
# verified             135
# review               133
# usefulness           135
# date                 135
# dtype: int64

# %%
data.count()
# Out:
# username             1996
# rating               1996
# initial_statement    1996
# country              1996
# verified             1996
# review               1979
# usefulness           1996
# date                 1996
# dtype: int64

# %%
data[data['country']=='Canada'].count()
# Out:
# username             14
# rating               14
# initial_statement    14
# country              14
# verified             14
# review               14
# usefulness           14
# date                 14
# dtype: int64

# %%
data[data['country']=='Canada']
# Out:
#                            username  rating  \
# 1849                Anthony Idemili       4
# 1853                       Abdullah       4
# 1884                  Denise Fidler       5
# 1897                      ebensiter       5
# 1898                    Annick côté       5
# 1899                       Jashugan       1
# 1900  Ivonise Morato de O. Capanema       5
# 1921                             HA       1
# 1967           Nelson Jean-Francois       1
# 1972                          Manno       1
# 1973            Huynh Hua Hoang Hai       1
# 1974                         Barath       1
# 1975                     Cindy 1010       1
# 1980                Parminder Singh       1
#
#                                       initial_statement country verified  \
# 1849                                        AirPods Pro  Canada        1
# 1853  Excellent condition of item. Bad battery life ...  Canada        1
# 1884  Buy New!!! These stopped working every 10 min ...  Canada        1
# ...

# %%
data.tail()
# Out:
#                     username  rating  \
# 1991  PEDRO VALDOVINOS GAONA       2
# 1992                  maac08       5
# 1993             Maximiliano       1
# 1994            Antonio Meré       5
# 1995                   diego       1
#
#                                       initial_statement country verified  \
# 1991        Que el producto esté en buenas condiciones.  Mexico        1
# 1992                                  muy recomendables  Mexico        1
# 1993  La caja de los audífonos me llegó , de que est...  Mexico        1
# 1994                                          Excelente  Mexico        1
# 1995         Audifono derecho COMPLETAMENTE inservible.  Mexico        1
#
#                                                  review usefulness       date
# 1991  El producto se descargaba muy rápido incluso l...          0 2021-06-24
# 1992                   excelentes para usar en llamadas          0 2021-06-01
# ...

# %%
data.count()
# Out:
# username             1996
# rating               1996
# initial_statement    1996
# country              1996
# verified             1996
# review               1979
# usefulness           1996
# date                 1996
# dtype: int64

# %%
data.shape[1]
# Out:
# 8

# %%
data['positive'] = data['rating'].apply(lambda x: 1 if x > 3 else 0)

# %%
data
# Out:
#                     username  rating  \
# 0             Asia underwood       4
# 1                      Katie       4
# 2              Sean Connolly       4
# 3                   Michelle       5
# 4                     Jayden       5
# ...                      ...     ...
# 1991  PEDRO VALDOVINOS GAONA       2
# 1992                  maac08       5
# 1993             Maximiliano       1
# 1994            Antonio Meré       5
# 1995                   diego       1
#
#                                       initial_statement        country  \
# 0     It has good noise cancellation the only proble...  United States
# 1                                 Love these Headphones  United States
# 2                                                 Solid  United States
# 3                                             BUY IT RN  United States
# 4                          Greta product slightly dirty  United States
# ...                                                 ...            ...
# ...

# %%
data['review'].isnull().sum()
# Out:
# 17

# %%
data = data.dropna(subset=['review'])

# %%
data['review'].isnull().sum()
# Out:
# 0

# %%
data.shape[0]
# Out:
# 1979

# %%
date_range = data['date'].min().strftime('%Y-%m-%d') + ' to ' + data['date'].max().strftime('%Y-%m-%d')

# %%
date_range
# Out:
# '2019-12-17 to 2023-02-21'

# %%
date_range_days = (data['date'].max() - data['date'].min()).days
date_range_days
# Out:
# 1162

# %%
data
# Out:
#                     username  rating  \
# 0             Asia underwood       4
# 1                      Katie       4
# 2              Sean Connolly       4
# 3                   Michelle       5
# 4                     Jayden       5
# ...                      ...     ...
# 1991  PEDRO VALDOVINOS GAONA       2
# 1992                  maac08       5
# 1993             Maximiliano       1
# 1994            Antonio Meré       5
# 1995                   diego       1
#
#                                       initial_statement        country  \
# 0     It has good noise cancellation the only proble...  United States
# 1                                 Love these Headphones  United States
# 2                                                 Solid  United States
# 3                                             BUY IT RN  United States
# 4                          Greta product slightly dirty  United States
# ...                                                 ...            ...
# ...

# %%
data['positive'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['verified'].unique()
# Out:
# array([1, 'Early Reviewer Rewards', 0], dtype=object)

# %%
early_reviewer_rewards = data[data['verified'] == 'Early Reviewer Rewards']
early_reviewer_rewards
# Out:
#              username  rating       initial_statement        country  \
# 787           John R.       4            Disappointed  United States
# 1218        Subzer089       5  Better than Beats Pro!  United States
# 1322         Bobbie S       5               No issues  United States
# 1360          Claudio       5                       👻  United States
# 1371  Amazon Customer       5              Airpod pro  United States
#
#                     verified  \
# 787   Early Reviewer Rewards
# 1218  Early Reviewer Rewards
# 1322  Early Reviewer Rewards
# 1360  Early Reviewer Rewards
# 1371  Early Reviewer Rewards
#
#                                                  review usefulness       date  \
# 787   Cost a lot more where I got them no one had th...          1 2020-01-04
# 1218  These surpassed my beats pro. Get them guys, w...          0 2020-01-06
# 1322                               Working good so far!          0 2020-01-09
# ...

# %%
data['verified'] = data['verified'].replace('Early Reviewer Rewards', 1)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_2472\3005961612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['verified'] = data['verified'].replace('Early Reviewer Rewards', 1)

# %%
data['usefulness'].unique()
# Out:
# array(['7', '6', 0, '3', '4', '5', 1, '14', '9', '24', '2', '16', '17',
#        '20', '11', '21', '13', '8', '31', '232', '18', '274', '10', '150',
#        '140', '168', '30', '12', '23', '55', '35', '370', '363', '505',
#        '40', '26'], dtype=object)

# %%
data['date'].unique()
# Out:
# array(['2023-02-01T00:00:00.000000000', '2023-02-02T00:00:00.000000000',
#        '2022-12-12T00:00:00.000000000', '2023-01-17T00:00:00.000000000',
#        '2023-02-15T00:00:00.000000000', '2023-01-26T00:00:00.000000000',
#        '2022-12-24T00:00:00.000000000', '2023-02-16T00:00:00.000000000',
#        '2023-01-04T00:00:00.000000000', '2023-02-13T00:00:00.000000000',
#        '2023-01-11T00:00:00.000000000', '2023-02-21T00:00:00.000000000',
#        '2022-12-04T00:00:00.000000000', '2023-01-21T00:00:00.000000000',
#        '2023-02-08T00:00:00.000000000', '2022-12-30T00:00:00.000000000',
#        '2022-09-23T00:00:00.000000000', '2022-11-21T00:00:00.000000000',
#        '2023-02-03T00:00:00.000000000', '2023-01-12T00:00:00.000000000',
#        '2022-11-06T00:00:00.000000000', '2023-01-22T00:00:00.000000000',
#        '2023-01-18T00:00:00.000000000', '2022-11-07T00:00:00.000000000',
#        '2023-02-07T00:00:00.000000000', '2022-10-15T00:00:00.000000000',
# ...

# %%
data['positive'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data.count()
# Out:
# username             1979
# rating               1979
# initial_statement    1979
# country              1979
# verified             1979
# review               1979
# usefulness           1979
# date                 1979
# positive             1979
# dtype: int64

# %%
data.to_csv('airpod_reviews_cleaned.csv', index=False)
